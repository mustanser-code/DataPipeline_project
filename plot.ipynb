# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('product_data.csv')
df
# Out:
#    id                          title  \
# 0   1  Essence Mascara Lash Princess
# 1   2  Eyeshadow Palette with Mirror
# 2   3                Powder Canister
# 3   4                   Red Lipstick
# 4   5                Red Nail Polish
# 5   6            Calvin Klein CK One
# 6   7        Chanel Coco Noir Eau De
# 7   8                   Dior J'adore
# 8   9             Dolce Shine Eau de
# 9  10             Gucci Bloom Eau de
#
#                                          description    category   price  \
# 0  The Essence Mascara Lash Princess is a popular...      beauty    9.99
# 1  The Eyeshadow Palette with Mirror offers a ver...      beauty   19.99
# 2  The Powder Canister is a finely milled setting...      beauty   14.99
# 3  The Red Lipstick is a classic and bold choice ...      beauty   12.99
# 4  The Red Nail Polish offers a rich and glossy r...      beauty    8.99
# 5  CK One by Calvin Klein is a classic unisex fra...  fragrances   49.99
# ...

# %%
category_count = df['category'].value_counts().reset_index()
print(category_count)
category_count.columns = ['category','count']
# Out:
#      category  count
# 0      beauty      5
# 1  fragrances      5

# %%
sns.barplot(data = category_count,
            x = 'category',
            y = 'count')
# Out:
# <Axes: xlabel='category', ylabel='count'>

# %%
# creating new chart on Average Price by each Category (Bar)

# %%
avg = (
    df.groupby('category')['price'].mean().sort_values(ascending=False)
)
plt.figure(figsize=(10,5))
avg.plot(kind = 'bar')
plt.title('Average Price by each category')
plt.xlabel('category')
plt.ylabel('Average Price ($)')

plt.xticks(rotation= 45)
plt.tight_layout()
plt.show()

# %%
# As we clearly see that Fragrances has higher price than beauty
