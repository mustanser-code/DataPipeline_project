# %%
import pandas as pd

# %%
df = pd.read_csv('product_data.csv')
df.head()
# Out:
#    id                          title  \
# 0   1  Essence Mascara Lash Princess
# 1   2  Eyeshadow Palette with Mirror
# 2   3                Powder Canister
# 3   4                   Red Lipstick
# 4   5                Red Nail Polish
#
#                                          description category  price  \
# 0  The Essence Mascara Lash Princess is a popular...   beauty   9.99
# 1  The Eyeshadow Palette with Mirror offers a ver...   beauty  19.99
# 2  The Powder Canister is a finely milled setting...   beauty  14.99
# 3  The Red Lipstick is a classic and bold choice ...   beauty  12.99
# 4  The Red Nail Polish offers a rich and glossy r...   beauty   8.99
#
#    discountPercentage  rating  stock                       tags  \
# 0               10.48    2.56     99      ['beauty', 'mascara']
# 1               18.19    2.86     34    ['beauty', 'eyeshadow']
# 2                9.84    4.64     89  ['beauty', 'face powder']
# ...

# %%
# checking for null values
df.isnull().sum()
# Out:
# id                      0
# title                   0
# description             0
# category                0
# price                   0
# discountPercentage      0
# rating                  0
# stock                   0
# tags                    0
# brand                   0
# sku                     0
# weight                  0
# dimensions              0
# warrantyInformation     0
# shippingInformation     0
# availabilityStatus      0
# reviews                 0
# returnPolicy            0
# minimumOrderQuantity    0
# meta                    0
# images                  0
# thumbnail               0
# dtype: int64

# %%
# no null value found 
# checking for duplicated values
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
# false means that the dataset has not duplicate value

# %%
# checking correct data type 
df.dtypes
# Out:
# id                        int64
# title                       str
# description                 str
# category                    str
# price                   float64
# discountPercentage      float64
# rating                  float64
# stock                     int64
# tags                        str
# brand                       str
# sku                         str
# weight                    int64
# dimensions                  str
# warrantyInformation         str
# shippingInformation         str
# availabilityStatus          str
# reviews                     str
# returnPolicy                str
# minimumOrderQuantity      int64
# meta                        str
# images                      str
# thumbnail                   str
# dtype: object

# %%
df.convert_dtypes()
df.dtypes
# Out:
# id                        int64
# title                       str
# description                 str
# category                    str
# price                   float64
# discountPercentage      float64
# rating                  float64
# stock                     int64
# tags                        str
# brand                       str
# sku                         str
# weight                    int64
# dimensions                  str
# warrantyInformation         str
# shippingInformation         str
# availabilityStatus          str
# reviews                     str
# returnPolicy                str
# minimumOrderQuantity      int64
# meta                        str
# images                      str
# thumbnail                   str
# dtype: object

# %%
# Change weight into float 
df['weight'] = df['weight'].astype(float)
df['weight'].astype
# Out:
# <bound method NDFrame.astype of 0    4.0
# 1    9.0
# 2    8.0
# 3    1.0
# 4    8.0
# 5    7.0
# 6    7.0
# 7    4.0
# 8    6.0
# 9    7.0
# Name: weight, dtype: float64>

# %%
# now i will start ploting that data and make useful insights from the data
# using python libraries (seaborn , matplotlib )
